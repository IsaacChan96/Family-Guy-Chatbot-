# %%
questions
# Out:
# ['American Inventor: The True Story of Henry Ford.',
#  "It'll flatten any Jew.",
#  'Could you also use it just to drive  from place to place and stuff?',
#  "It's not what it's designed for.",
#  'Yeah, yeah, you cou Yeah, yeah, you-you could',
#  ' Oh, hey, Quagmire.',
#  "Peter, you know this is a pilot's uniform.",
#  'Yeah, well, you know what else takes years',
#  'MAN (Korean accent): Hold still.',
#  "You've earned your nickel this week.",
#  'I had to fly to Aruba, so I brought my mom along',
#  'Yes, Joe, I got you a magnet.',
#  'Well, you know I have that fridge in the garage',
#  'Oh, airline employees can get discounted tickets',
#  "If I'm being honest, I've also got  a few Celeste pizzas in that fridge.",
#  ' just figured you guys  always have to work,',
#  ' could take you somewhere.',
#  'San Francisco?',
#  "I'm in!",
#  "Oh, wow, this'll be great.",
#  'What a surprise.',
#  "Okay, I'm off to Hilton Head with the girls.",
#  ' Peter,  I told you about this a month ago.',
#  "I'm going with Bonnie and Donna  to Donna's sister's time share.",
#  "I'm sorry, Peter, but I already have a taxi waiting.",
#  'Why is he taking his suitcase to tell the guys?',
#  "QUAGMIRE: I'm in the shower.",
#  'Oh, and the idiot took my suitcase.',
#  '(indistinct conversations)  Ah, San Francisco.',
#  'Aah! San Francisco!',
#  'I want to see the Golden Gate Bridge.',
#  'I want to see Ghirardelli Square.',
#  "Let's get lesbian haircuts and see 'em all.",
#  'Oh   Crawl inside ',
#  'Wait by the light of the moon   Come to my window ',
#  "I'll be home soon   I'll be home, I'll be home ",
#  "I'm coming home   All right, the gay jokes",
#  'Okay, guys, this is the original Levi Jeans factory,',
#  'Well, then you plan the vacation!',
#  "Peter, Peter, calm down, it-it's okay,  we'll-we'll do whatever you want.",
#  "I was thinkin' we could tuck our shirts into our pants,",
#  'You guys, look.',
#  "Oh, my God, Steph, I'm such a big fan.",
#  'Hey, I know we just met, but can I sit on your lap',
#  'This is exciting for the whole Bay Area,  to be just four games away',
#  "That other team's not just gonna go away, though.",
#  'Fat lady. Dad, Dad, a fat lady.',
#  'Make her go.',
#  'Make her go.',
#  "Yay! I'm learning bad lessons.",
#  "I didn't realize how hilly it was gonna be.",
#  'Hey, no problem.',
#  'You guys want a little tour of the plane?',
#  "Normally I'd just go to Hudson News  and pretend to be",
#  'Yes, I will have eight Dasanis  and a JD Power & Associates.',
#  'Wow, this place is cool.',
#  "Like, what's this red one?",
#  "What? That's impossible.",
#  'AUTHORITATIVE VOICE: Good afternoon, folks,',
#  "We've reached our cruising altitude of 37,000 feet.",
#  'Our in-flight entertainment today  will be Under the Tuscan Sun.',
#  "I hear it's good.",
#  'Oh, that allows the plane to fly itself when I need a break.',
#  "You don't have to fly the plane?",
#  ' short break sometimes.',
#  "You don't have to touch it, Joe, you can just say you noticed it.",
#  "Oh, that's my back-in-time box.",
#  "By God, we're levitating.",
#  "It's my back-in-time box!",
#  "That's not true.",
#  "It's Dumbledore!",
#  'I was a Navy pilot, you jerks.',
#  "Joke's on him. I farted just before he kicked us out.",
#  "All right, let's see what's in the in-flight magazine.",
#  'Already filled-in crossword puzzle.',
#  'All right, time to use the potty.',
#  'Okay, nobody move!',
#  'Cleveland, just be happy with what you have.',
#  "No, Peter, we're being hijacked.",
#  '(Eastern European accent): This plane now belongs to us.',
#  'So nobody try to get smart.',
#  'Control tower, this is flight 364.',
#  '- Our flight has been - (static)',
#  'Oh, damn it, they jammed the transmission.',
#  'Hello? Can you hear me?',
#  "We're being hijacked.",
#  'This is your last chance.',
#  "No. I'm landing at the closest airfield,  which is less than an hour away.",
#  '(grunts)  QUAGMIRE: Aah! Jimmy! Oh, my God!',
#  'Why are you doing this?',
#  'Which country?',
#  'The second thing.',
#  '- executing passengers.',
#  'Man, coming on this trip was a terrible idea.',
#  "I'm Joy.",
#  "I'm Anger.",
#  "I'm Poo.",
#  'Ooh, I need to use the bathroom.',
#  '  We interrupt this program with a special report.',
#  "Oh, my God, that's your father's flight.",
#  "I'll be here to update you as this story progresses.",
#  ' couple in their 30s  gets married without their dog',
#  "What's it gonna be?",
#  "QUAGMIRE: I'm not opening it.",
#  'You, fat guy. Get up here!',
#  '(grunts)  Last chance. Open the door,',
#  "Don't open it, Quagmire.",
#  'Wait wait, what?',
#  "I'm sorry, Peter, but I have to think about the whole plane.",
#  'Oh, man, we got to help Peter!',
#  'You know, I have a gun in the bag I checked.',
#  'Good idea, Joe.',
#  "You're right, it does. There's even an impatient businessman",
#  'My shirt is blue, but the collar is white.',
#  "Quick, he's distracted.",
#  '\\"Get off my plane.\\"  - What\'s that, now?',
#  ' Hmm?',
#  '\\"Always bet on black.\\"  \\"Always bet on black.\\"',
#  '- Did you say something?',
#  '- \\"Double trouble!\\" - \\"Double trouble!\\"',
#  "That's it. We found it.",
#  'Hey! Two of the passengers are missing!',
#  "I'll go find them.",
#  'Oh, nice. Last guy picked for dodgeball,  first guy for human shield.',
#  ' Everybody be quiet!',
#  "Good afternoon. I'm Tom Tucker.",
#  ' missing airliner continues,  as speculation grows that',
#  "What will our lives be like if our husbands don't make it?",
#  '  Travel down the road and back again   Your heart is true ',
#  "You're a pal and a confidant   Thank you for being a friend ",
#  '(song ends)  Oh, my God! Now I want Dad to die!',
#  'Hey, Joe, look at me.',
#  "Get out of people's stuff!",
#  '(elevator whirring)  Hey! What are you two doing down here?',
#  "Oh, someone's shipping live lobsters.",
#  'Prepare to die.',
#  "That's what you think.",
#  'Peter! Grab on to something!',
#  '(shouting)  (grunting)',
#  '(choking)  (grunting)',
#  '(shouts)  (shouts)',
#  "QUAGMIRE: Attention, passengers, I know we're being hijacked,",
#  'Wow! That is truly awe-inspiring!',
#  "And you know what you don't see from up here?",
#  '  (screaming)  Die in hell, Eurotrash!',
#  'Hang on, Peter!',
#  "Joe, how'd you know that lever would open the landing gear?",
#  'I notice every wheel in a room as soon as I enter.',
#  'Special delivery from the U.S. of A.!',
#  'Aw, rats.',
#  '(screaming)  (grunting)',
#  'Get off my pl Double trouble!',
#  '(cheering and applause)  Oh, my God, you guys did it!',
#  "We're saved!",
#  'So, if I sign this, the war is over,  we surrender, and we still',
#  'You can all relax now, everybody!',
#  "Looks like you'll make that business meeting after all.",
#  '(Eastern European accent): Now reach for it.',
#  'Yes. I was in reserve in case the plan went awry.',
#  'Las Vegas.',
#  "'d lose my life there.",
#  ' Yeah, just now.',
#  'I know I crap on you a lot, but sometimes,',
#  '- Thank you, Peter.',
#  'Very good. We are less than 20 minutes from Las Vegas.',
#  'Get ready to say good-bye to your precious Rita Rudner.',
#  "No. We're going to crash into the biggest hotel on the Strip!",
#  'You know, we never quite nailed down  what region you guys are from.',
#  'Good afternoon.',
#  "As you can see, I've taken off my blazer  to show the severity of the situation.",
#  "It's apparently veered off its flight plan",
#  "Now here's an over-the-top news graphic.",
#  ' (screaming)  ANNOUNCER: Nightmare over Vegas.',
#  '(explosions)  - (slot machine music, coins clinking)',
#  ' Hijack Jackpot.',
#  'Hey, buddy, wake up.',
#  'What? What are you talking about?',
#  'Nobody wants to die in their sleep.',
#  'There you go.',
#  'Us? What about you?!',
#  'I mean, nobody\'s ever been like, \\"Yeah, yeah, more guy noises.\\"',
#  'They ask us to do that to cover up the sound',
#  'So, uh, you ever been to Vegas before?',
#  "Well, I think you're gonna  flip for it!",
#  '(grunts)    Attention, passengers, the plane',
#  "(groaning, moaning)  Oh, come on! Doesn't anybody",
#  'That was some quick thinking, Glenn.',
#  "Missiles? That's a military fighter jet!",
#  '- Or \\"she.\\" - What?!',
#  'They must think the hijackers still control the plane!',
#  "Don't worry, I'll signal to 'em.",
#  "See? We don't need your help!",
#  "I've got a visual on the terrorists.",
#  'He must be an important businessman.',
#  "(whirring)  Oh, good, he's movin' away.",
#  "No, he isn't. He's g getting in position to fire!",
#  'Everybody in your seats!',
#  'Quagmire, land this plane!',
#  'Oh, God, this is it!',
#  'Like hell we are!',
#  "  We're going too fast!",
#  "Oh, no, we're not!",
#  "QUAGMIRE: Oh, yeah, right there. That's good.",
#  'PETER/QUAGMIRE/JOE/CLEVELAND: Giggity.',
#  '(indistinct radio transmission)  Wow, Quagmire, thanks for',
#  "We're sorry for saying your job was easy.",
#  "He's right. What you did up there was amazing.",
#  "Boy, that was quite a trip, wasn't it?",
#  " lot about blue jeans,  - didn't we, guys?",
#  ' Yes, yes, we did, yeah.',
#  ' Thank you for planning a wonderful day.',
#  '- Cleveland!',
#  'Peter!',
#  "I think you'd prefer to keep private.",
#  'I think we will.',
#  "Well, let's head home.",
#  'Sounds good.',
#  'COMMENTATOR: Wide open in the end zone.',
#  'Beautiful pass by Tom Brady.',
#  "He's awesome.",
#  'I wish I was a supermodel.',
#  'Jerome, switch over to the RedZone.',
#  "- What's that?",
#  'They show every sex scene on TV  without all the boring',
#  "Hey, we're gonna split the screens now  because my producer is telling",
#  "'cause it's Gabby Hoffmann Donald Ducking it.",
#  "We don't want to bring you dead boobs,  but if they're alive,",
#  "It's almost 3:00. I got to get out of here.",
#  "Eh, the airline's making us all attend a seminar",
#  "Really? I didn't see that in the newsletter this month.",
#  '(siren wailing)  (laughs) Wait till they',
#  "No, It's a serious problem.",
#  '- Oh.',
#  '- Oh!',
#  '(louder): Oh!',
#  ' drone right now?',
#  'Owning a drone is gonna be a blast.',
#  ' had breakfast in bread.',
#  "Yeah, I don't know what this is Peter,  but we're four months",
#  "It's not like we're short on dough.",
#  "'m staying at my parents'  for a while.",
#  '  Ah, Brian, you finally made it.',
#  'Yeah, you texted me, like, 80 times.',
#  "Yeah? Tell me why you don't have time.",
#  "And there's nothing pretend about this.",
#  'Wow, this is good.',
#  "I didn't, I'm raising bees.",
#  'Like-like a beekeeper?',
#  "Mmm, I got to say, you're good at it.",
#  "Really? You think it's that good?",
#  "It's straight from the hive.",
#  'You know, you could probably charge, like, $20, $30 a jar.',
#  'I feel like an eighth grader who just had sex.',
#  'Oh, yeah.',
#  'Hmm, how can I prove it?',
#  '- Oh!',
#  '(crying): He said he loved me.',
#  'Drone of Arcadia.',
#  'I love that show.',
#  '(drone powers up)  Can I have a turn? I want a turn.',
#  'No.',
#  'No.',
#  '(airplane engine)  (motor mower)',
#  '(grunting)  (splash)',
#  'JOE: Check it out, here comes a hawk.',
#  '(wings flapping)  Uh-oh.',
#  "What's happening?",
#  ' Ah, no!',
#  'JOE: Look at that pervert squirrel just watching.',
#  "(drone engine starting)  Oh, crap, it's busted.",
#  "And I bet it's completely traumatized.",
#  'It was planned.',
#  "  I've been a bad drone.",
#  "Peter, you've been knocking a while.",
#  'Yeah, look at all this mail.',
#  "Oh, my God, he's dead!",
#  "(cat yowls, all scream)  Oh, that's a relief.",
#  "It's just the cat that ate his face and ears off.",
#  'Now, how many bees do you think are in here?',
#  "No, it's 4,000.",
#  "All right, now, if you're going to sell honey",
#  'Ooh, what do we have here?',
#  'Like the sign says.',
#  'May I speak to your manager?',
#  "I'm sorry, is there a problem here?",
#  '- How do we have a back?',
#  'Stewie, this is ridiculous.',
#  'Oh, my, and I thought only bees pour on the honey.',
#  'So, are you from around here?',
#  '- at the museum.',
#  "I've been looking for an excuse to go again.",
#  'Great. Give me one minute.',
#  'Your what?',
#  ' That was Bonnie.',
#  'Poor Mr. Seigel.',
#  ' What the hell is that?',
#  "MAN 2: Yeah, let's go, let's go.",
#  ' Yeah!',
#  '- What is it?',
#  '- (dreaming music) - 87?',
#  "That's not a van, Lois, that's a party bus.",
#  "Who's that?",
#  '  Did you guys see?',
#  '(men continue cheering)  (tyres skid)',
#  '(all breathing heavily)  (out of breath): Am I running?',
#  'Is this what running is?',
#  "  What's up, butt munchers?",
#  "We're butt munchers!",
#  'All right, time to Gronk a dump in my new house.',
#  'Oh. My. God!',
#  "Hey, I'm your new mailman.",
#  'On any other day that would be so exciting.',
#  'What the hell are you doing?',
#  "You're bringing him a bowl of powder?",
#  "Peter, I don't know what you're so excited about.",
#  "You know he's gonna be partying day and night.",
#  "Now there's a Patriot you can get excited about.",
#  "(gruff voice): I'll take it all.",
#  '(fizzy drink shaking)  Ah!',
#  '(relieved sigh) Anyway,  go suck up to your big dumb monster.',
#  '"G\\" to thoughts of Edelman.',
#  "(doorbell rings)  So, what'd you get him, Cleveland?",
#  'Oreo middles.',
#  "No, we're people, sir.",
#  'I live in the house behind yours.',
#  'Awesome!',
#  'Ha-ha, he spiked it.',
#  'My eyes!',
#  'You want to come in and eat pizza standing up?',
#  ' Cool.',
#  "I don't like learning names.",
#  'Well, come on in, Grover.',
#  '(indistinct conversations and music)  Oh, my God, you guys, having',
#  'Kind of like those years when it was just Marley and me.',
#  "Hey, my dirty dog's jumping in the neighbor's pool.",
#  "I'm gonna lay down these work blueprints on the floor",
#  'Aw, my nightmare dog is dead.',
#  '(party sounds)  Workout room, kegerator cellar,',
#  "I-Is that just 'cause of the danger?",
#  "My dumb wife won't let me have a room like that.",
#  '(laughing)  (chuckles nervously)',
#  "What's going on?",
#  'Check it out, my hot tub is filled with coffee.',
#  "Sponsored by Dunkin' Donuts.",
#  'Sponsored by Campbell Soup.',
#  'What\'s a \\"albaphet\\"?',
#  'And check out the shower!',
#  'Sponsored by Monster Energy Drink.',
#  "My manager said if I don't,  I won't go to heaven.",
#  'Sponsored by SMS Audio Sweatproof Sport Headphones.',
#  "You've got your yoga pants moms,  you got your mixed-race",
#  'A vegetable parking lot?',
#  "We're not a restaurant, that doesn't make any sense.",
#  'Say anything-to-anything,  people lose their minds.',
#  '- Ooh!',
#  "That'll be $68.",
#  'Total superfood. Full of GMOs.',
#  'No GMOs whatsoever.',
#  "Wow, this is great,  we've only been here an hour",
#  "Just like Dan Cortese  didn't see the end of the '90s coming.",
#  'Happy New Year!',
#  'Dan Cortese was the only thing in the entire world',
#  'Grovers, you made it!',
#  'Thanks.',
#  'I always wanted to ask you.',
#  "I don't know,  want to see me dance?",
#  'A-Am I am I supposed to touch you?',
#  "Oh, I'm sorry, bro.",
#  'Like, a secret hand signal or something.',
#  '(belches)  How rude.',
#  'Hey, want to meet my family?',
#  "Actually, one of them is my dad,  I'm not sure which.",
#  'Probably the gray-haired one  with the whiskey-face sunburn?',
#  'You must be very proud.',
#  "I think every dad's dream  is taking his son's sloppy seconds.",
#  "They don't have a mom.",
#  "God bless her, but genetically,  they're a product of me",
#  'How are we gonna do that?',
#  "This here is the same stuff  that turned Barry Bonds' head",
#  'Hmm.',
#  "I don't know, how many bees is a horse?",
#  'That makes sense.',
#  'Time for bed, Barry.',
#  'Turn down for what   (distant):  Turn down for what ',
#  "God, they're still going?",
#  ' told you would happen!',
#  "(music stops, applause) Oh, thank God,  maybe they're wrapping it up.",
#  'Noise!   Loud noise, noise ',
#  'And a Civil War cannon.   (cannon fires)',
#  "Damn it, I can't take anymore!",
#  "You won't believe what he did yesterday.",
#  '(techno music playing)  (cheering)',
#  '(music stops)  Uh, listen, Gronk, um,',
#  "Don't you think maybe it's time to call it a night?",
#  'Hey, you ever seen a nard explode?',
#  "I don't  Is that something on the Internet?",
#  "Uh, 'cause I  Ah, damn it, what the hell?!",
#  '(laughter)  MAN: Oh, nice shot there.',
#  "Come on, don't get mad, bro.",
#  'You were kidding?!',
#  'This was!',
#  '- MAN: Oh!',
#  'Yeah.',
#  "You're a jerk, Gronk!",
#  "I'm getting rid of that bastard.",
#  'This tyranny shall not stand!',
#  "Ah, crap, he's even in the cutaways!",
#  '(breathing heavily): Just Just go to commercial.',
#  '(party music playing)  Peter, you got to figure something out.',
#  "They haven't stopped partying the whole night.",
#  ' MAN 2: Gronk!',
#  "I'm sorry, you were right all along.",
#  'Well, you better do something soon.',
#  "I know. That guy's more annoying  than going to an Italian restaurant",
#  'More like a ristorante to me.',
#  'Supposed to be the hills of Elba?',
#  'Are you ready to order?',
#  'Two spaghettis and a chicken fingers.',
#  'Those steroids were a great idea, Stewie.',
#  'Hey, look, that bee is trying to get our honey.',
#  'After all, you  - (yells)',
#  ' Holy crap!',
#  ' whole jar of honey!',
#  "(buzzing)  Well, this one's wearing",
#  ' hoodie as a shirt.',
#  'Stewie, I have a bad feeling abo  Oh, God, it just ate the other bee!',
#  'Okay, so a few of them had a bad reaction to',
#  ' Oh, crap.',
#  'Oh, my God. Brian, run!',
#  'I think maybe giving those bees steroids  was a bad idea.',
#  ' (gasps)  Turn on the wipers!',
#  '(Brian and Stewie yelling)  (muffled music playing)',
#  'You sure this is gonna work, Peter?',
#  'Gronk went to the University of Arizona,  and everyone who went to',
#  ' green suit and a top hat  This is my Easter clothes.',
#  '(doorbell rings)  Whoa, a leprechaun!',
#  'Say the thing.',
#  'Mr. Gronkowski.',
#  'All you have to do is move to Tallahassee!',
#  'Aah, son of a bitch!',
#  'Are you guys trying to get rid of me?',
#  'Why?',
#  'I mean, what the hell, Gronk?',
#  "You're a millionaire,  you have the sweetest job in the world,",
#  "It's not a choice, Grover.",
#  "You see, I've been groomed for this  my entire life.",
#  'All in the name of entertainment.',
#  "I'm a commodity, a product.",
#  'You ask about the whys and the wherefores',
#  'I play the jester because society deems it necessary.',
#  '(laughing)  Eat a butt, fatty!',
#  "Gronk ain't going nowhere!",
#  "(all grunting)  Oh, cool, we're fighting?",
#  'You guys mind if I eat while I beat you up?',
#  '(tires screeching)  What the hell are we supposed to do?',
#  "We're surrounded!",
#  '\\"Meg, come outside.',
#  '- (buzzing) - (Meg yelling)',
#  'Ow! Ow, ow! Stop stop it!',
#  'Quick! We just have to get rid of the queen!',
#  "What's that gonna do?",
#  'Okay, great, but how we gonna do it?',
#  '(all straining)  (grunting)',
#  'You guys are bad fighters.',
#  'Ah, cool!',
#  'Aah, oh, my God,  is that a bee?!',
#  "Uh, yeah, it's the world.",
#  'Holy crap!',
#  'Dad, start up the party bus!',
#  'DAD GRONKOWSKI: Bees?',
#  "And they're showing blitz!",
#  '(buzzing)  (party music playing)',
#  '(tires screeching)  You think their Wi-Fi is \\"Vag-Town\\"?',
#  "Yeah, that's probably them.",
#  'Oh, well, thank goodness  we finally have our neighborhood back.',
#  'Peter, that was Home Improvement.',
#  "Coming up, yesterday's brisket.",
#  'But first, breaking news:  Rob Gronkowski has been',
#  'The star athlete claims he has no idea  how the banned substance',
#  "That's terrible.",
#  'Mr. Gronkowski said simply,  \\"Grover, go long.\\"',
#  'Uh-oh.',
#  '    ',
#  "Probably. But I don't want to think about it.",
#  'I spend most of my day breaking up  - in-progress homeless sex.',
#  ' I bet it stink.',
#  'So we talking group stuff or just one-on-one?',
#  "There's a major hot spot behind the Dumpster",
#  'Why they got to be so big?',
#  'I go there for dinner, not to shop for appliances.',
#  "Ah. That's actually not a bad idea.",
#  'Uh, definitely not anyone with a computer can make one.',
#  "Let's do a podcast from right here in the booth.",
#  "- Let's do it!",
#  'Is it happening? Are we doing it now?',
#  'PETER (WHISPERING): Guys, look.',
#  'OTHERS: Oh! Ooh!',
#  "It's feathered crown is designed to scare away mates.",
#  'CLEVELAND: What does it eat, Peter?',
#  '  I said, damn, what a wild couple of days.',
#  'Sorry, amigo, not interested.',
#  'This is what happens when you lick your spilled latte',
#  '- Lois, are you okay?',
#  "It's just my allergies.",
#  "(SNEEZES)  Maybe it's Brian.",
#  'He practically sleeps on top of you.',
#  "Hey, here's an idea, Chris  why don't you mind your own business?",
#  "Brian, maybe you shouldn't sleep in our bedroom",
#  ' What?',
#  'How about in your own apartment, like a grown-up?',
#  "Why don't you sleep in Stewie's room?",
#  "Roomies? Dude! This'll be so ill!",
#  " I'll tell you who.",
#  "(SNEEZES, GROANS)  I'm gonna go take a shower",
#  '(GRUNTS)  Damn it! I hate this house.',
#  '- Morning, honey!',
#  '  All right, you guys, podcast time.',
#  'Ready?',
#  "I'm here with Glenn Quagmire,  - Hi.",
#  ' Cleveland Brown  - and',
#  ' Hello.',
#  'Yo-zah!',
#  "Let's make a clam-ory.",
#  '-You ready, Peter?',
#  '- Yes.',
#  '- Yes.',
#  "I-I don't know. These questions are weird.",
#  'Cleveland, yes or no.',
#  ' Hmm, Velcro shoes.',
#  "I remember the first time I saw me a pair of 'cro's.",
#  'Man, they was dandy  Every time we played touch football,',
#  'Spunky would step in a pile of dog poo.',
#  "That's why Spunky made the change.",
#  'Quiet going on, noisy coming off.',
#  'Shot him right in the face.',
#  'But only open on the middle part  To this day, every time I',
#  'I take a step in it just for Spunky.',
#  "'m gonna have to say  both yes and no.",
#  "I'd like to thank our sponsor, the U.S. Postal Service.",
#  '.S. Postal Service.',
#  'I know! Cleveland, you ruined the whole podcast.',
#  "- I'd watch Family Feud.",
#  "Anyway, my brother Louie, he's a  he's a little off to the side, you know?",
#  "He's a he's a backwards mechanic.",
#  ' You mean gay?',
#  ' Mama!',
#  ' Marone! Peter!',
#  '  Hey, Stewie, thanks for letting me stay in your room.',
#  'Hey, what are we gonna do tonight?',
#  'Keira Knightley to orgasm?',
#  ' I saw that scene.',
#  'So, I was thinking this could be your area.',
#  'And fair warning Some of the books are pop-up,',
#  ' Aah! Son of a bitch!',
#  'You know, I have a good feeling about this, Brian.',
#  '- What the?',
#  "She's already very angry at me.",
#  'Shh, shh.',
#  '  You know, this is exciting.',
#  'All right, but listen up, Cleveland.',
#  "Yeah, people aren't used to boring podcasts.",
#  "'cause sometimes I get on a roll.",
#  'J N-None of that.',
#  'Okay, common question that everybody thinks about.',
#  '- What?',
#  "So, like, what's what's the real number?",
#  "Let's say a hundred.",
#  '- Why are we fighting, now?',
#  'Did they say something about my mother?',
#  "- Oh, then a baker's dozen.",
#  "Only what's available in the schoolyard.",
#  'Just da-da-da-da-da-da-da-da-da!',
#  "'d back into a bathroom stall,  and just start kickin'.",
#  "Dead! Dead! Anyway, I guess I'm trying to say",
#  'Why are we talking about killing kids?',
#  "I'll-I'll uh, what if I play some kick-ass music?",
#  'Kick-ass? This is not kick-ass.',
#  "'ll find something.",
#  'ITH \\"THE GAMBLER\\")  You\'re playing two songs at once.',
#  '- What even is this?',
#  "I'm just pressing buttons!",
#  'Look! Those people are even dancing to it.',
#  "That the secret to survivin'   Aw, great! I accidentally",
#  'LOIS (ON VIDEO): Ow! O-O-O-O-O-Ow! Ow!',
#  'Ow! Kill me!',
#  "I don't know, it's just random garbage from my computer.",
#  'I own a nightclub for cocaine people and Armenians.',
#  "- We're in!",
#  "I'll see you guys Wednesday at 2:00 a.m.",
#  "Peter, I don't know if you noticed,  but the podcast was a disaster.",
#  'But how can I be a deejay?',
#  "Trust me, you're perfect.",
#  'Okay, but hold on. I got four quarters on Golden Tee.',
#  'How am I doing?',
#  '(QUIETLY): He just keeps switching clubs.',
#  "I think he's getting ready for his deejay gig.",
#  '(TECHNO BEAT PLAYING)  Hmm. Still a trace of melody.',
#  "I'll just add some power tools.",
#  "HIRRING, RATTLING)  Yeah. Yeah, I'd drink vodka",
#  'Peter, since when are you a deejay?',
#  "Well, he's got the lingo down.",
#  '- Now, scream!',
#  'Hey, you are good at this, Dad.',
#  "You can't be a deejay.",
#  "For God's sake, John Travolta's a pilot.",
#  'We have reached our cruising altitude.',
#  "(DING)    Well, what's all this?",
#  'Oh, just some stuff I got out of my storage unit.',
#  'Do I look like a Terminator dog?',
#  ' Yeah, I do.',
#  '\\"Sell rights to Saving Private Ryan residuals',
#  '\\"Miss audition.\\"  \\"Scoop someone\'s urine',
#  'Feels like we should be moving these pieces backwards.',
#  "ANNOUNCER: Okay, let's make some noise  for Deejay Peter and the Sound Slap!",
#  '(ELECTRONIC EXPLOSION)  QUAGMIRE: Giggity,',
#  "Give it to 'em.",
#  'Sh-Sh-Shut up, Meg.',
#  'Butt scratcher! Butt scratcher!',
#  'LOIS: Peter, Peter, Peter  CLEVELAND: Roadhouse. Roadhouse.',
#  "That's nasty. That's nasty.",
#  'This place is awesome!',
#  "(TECHNO BEAT CONTINUES)  You've been playing the exact same song",
#  "That means you're great.",
#  'Weird you turned that into a compliment about yourself.',
#  "My kid's baseball team came in second place.",
#  "But listen, there's a big music festival coming up.",
#  'You could be our headliner.',
#  "Yeah, it's gonna be awesome.",
#  " Well, I don't know.",
#  "What? You don't need the guys.",
#  'Huh. I guess I do have a gift.',
#  "Yeah, that'd be amazing.",
#  '- Excuse me?',
#  'Someone gave me a pill, and now all I want to do',
#  'No, no, stay here. Stay here.',
#  "You can't hear that on a CD.",
#  "I'm glad we hung out after you struck out with my mom.",
#  "- Who's this turd?",
#  'Brian, I never said you could have guests.',
#  'Okay, red flags flying.',
#  "You can't kick him out. He's my friend, and I live here, too.",
#  "Well, it's not your room anymore, it's our room.",
#  "I can't believe I ever wanted you here in the first place.",
#  '  Hey, Bri. You want to hang out?',
#  "And put on a shirt. You're 50.",
#  '  (SCRATCHING)  (KNOCKING ON DOOR)',
#  'Peter, I was plowing this college chick last night,',
#  "Well, yeah. That's the thing.",
#  "So what, you're just dropping us?",
#  'All right, you know what? You guys were riding my coattails.',
#  'Now, get out of here. I got to practice.',
#  'Turn it down.',
#  "It's not loud until you can feel your head bones.",
#  "Why's he being such a jerk?",
#  "We've always had each other's backs,  like when we used to rob banks",
#  'Um. Who are you guys supposed to be?',
#  "He's Millard Fillmore.",
#  'JOE: First president to die in office.',
#  'Why?',
#  "The wheelchair doesn't define me!",
#  "It's funny, 'cause my name's Cleveland.",
#  '(COCKS GUN) This guy gets it first.',
#  "Ugh. Didn't you hear the alarm?",
#  "We're gonna be late for church.",
#  "You've got to stop coming home so late  if you can't get up in",
#  '(HEART BEATING)  (SILENCE CONTINUES EXCEP FOR HEART BEATING)',
#  "Oh, God. I can't hear Garfield.",
#  '  All right, now how long has your husband smelled like this?',
#  'Hearing?',
#  "Oh, for God's sake, is my husband deaf?",
#  'Hey stupid deaf guy!',
#  'This is horrible.',
#  "What's going on? Can he fix it in time  for me to deejay at the music festival?",
#  ' What?',
#  ' What?',
#  '- Yes.',
#  '(LAUGHING): Have a good life.',
#  '- You what?',
#  "Oh, you're ear crippled?",
#  "Here's a bag of Alpha-Bits.",
#  'Oh, there\'s no \\"L\\" s.',
#  '"L\\" s. They\'re delicious.',
#  ' What are you talking about?',
#  ' What?',
#  "You know, that's a good idea.",
#  "You told us you were a big shot deejay  and didn't want anything to do with us.",
#  "I don't think he can hear it.",
#  'Oh, what do I want?',
#  "Now that I'm deaf, I can't do it without you guys.",
#  'Well, now you can go to hell.',
#  'I knew I could count on you guys.',
#  ' What?',
#  'One, two come on.',
#  'Eww. What the hell is that?',
#  "It's like a long rat.",
#  "Eww. They're gross.",
#  'You want to pet it? It bites.',
#  "That's the idea. I want you out.",
#  'Why you being such a dick about this?',
#  'What did you just do?',
#  '(YELLING)  (BOTH GRUNTING)',
#  'Oh, Brian, there you are.',
#  'What? I can?',
#  'He stuffed all our pillows with hay  because he thought it looked',
#  'I guess you are.',
#  'I probably got a little carried away.',
#  'Hey, Brian.',
#  "I'm sorry.",
#  "You know, even if we were bad roommates,  we'll always be good friends.",
#  "Well, now that you're moving out,  I'll probably just drown it in the tub.",
#  '(SCREAMS)  Brian! Brian! Ah!',
#  "It bit my nose. He's latching on.",
#  'Fill the tub, fill the tub!',
#  'When you went deaf, did your other senses get better?',
#  "Chances are you'll be hit by a bus  in the first three months.",
#  'Uh, damn it. Being deaf sucks.',
#  'Ho-ho, ho-ho.',
#  '(SIGHS) You know, the worst part of all of this',
#  "I don't blame them for not wanting to help me.",
#  'QUAGMIRE: We heard you, Peter.',
#  'You got to throw something at him.',
#  'What are you guys doing here?',
#  "All right, Peter, it's all cued up.",
#  'Okay. Here we go.',
#  'NARRATOR (OVER COMPUTER): Audible dot com presents,',
#  "Peter, that's the wrong track.",
#  'CHELSEA HANDLER: Chapter one.',
#  'Yep.',
#  'CHELSEA HANDLER: Soup thermos Yep.',
#  'Yeah. Awesome, huh?',
#  'CHELSEA HANDLER: Brother brand, all-in-one fax, scanner, color copier',
#  '  Well, bad news.',
#  'I got fired from the club.',
#  'Did you get your hearing back?',
#  'It was the fistfuls of Oxycontin.',
#  "Sorry it didn't work out for you.",
#  'I just appreciate that you guys  were there for me and',
#  "Well, it's good to have you back to normal, Peter.",
#  "I'm up on Big Buck Hunter.",
#  "We didn't even put quarters in the game. He don't know.",
#  'Ugh. This is gonna suck.',
#  'Yeah, back in my day you had to be a triple threat',
#  'I sure was.',
#  "  I'm a Yankee Doodle Dandy   Eight pounds!",
#  'Yankee Doodle do or die   12-nine! A big one!',
#  'A real live nephew of my Uncle Sam   Born on the Fourth of July ',
#  "Three pounds? Someone couldn't wait to be here.",
#  'Did that really happen?',
#  'The show is about to start.',
#  'Yes. Everything takes him longer these days.',
#  "Hey, Lois, look over there It's Jessica Chastain.",
#  "You're blind as a bat.",
#  '5 performances tonight  - WOMAN: You got to be kidding!',
#  ' MAN: Son of a bitch!',
#  'RUTH: It\'s \\"Coke-a-mer\\"!',
#  '(INTRO TO \\"NUTHIN\' BU A \'G\' THANG\\" PLAYING)  One, two, three and to the four ',
#  'Meg Meggy Meg and Dr.',
#  'Monsanto equals murder!',
#  " That's enough.",
#  "You can't silence the truth!",
#  "It's over, Patty.",
#  "Okay, up next, here's Evelyn Fong,  our 11-year-old high school junior.",
#  '(PLAYING BEAUTIFUL, LILTING MELODY)  (MELODY ENDS)',
#  'Oh, my God.',
#  "It's it's the most beautiful thing I've ever heard.",
#  'And now, two football players are going to do something',
#  'This is an away game?',
#  " It's true!",
#  '(CHUCKLES) Those are the kids I bought beer for.',
#  " Daddy, you can't see.",
#  'I can see fine.',
#  'One of you will have to sit next to me.',
#  '(FOOTBALL PLAYERS LAUGHING)  PLAYER: Oh! He talked',
#  '(PLAYER LAUGHING)  (URINATING) How are you, gentlemen',
#  'Dude! What the hell?',
#  'Hey! Jessica Chastain!',
#  "I wish I hadn't!",
#  "Well, tha-that's why the whole family came to support you.",
#  "Oh, uh, well, as you know, I'm here.",
#  ' Uh, Stewie and Brian.',
#  "That doesn't sound like the whole family.",
#  "It's me, Peter. Shipoopi.",
#  "(LIKE CHRIS): I-I'm here, too, Grandpa.",
#  "Aw, I don't care.",
#  'I recommend you and your wife have someone around',
#  "He's constantly crying for no reason.",
#  'Ow! Bitch!',
#  'You know, maybe Brian could help you.',
#  "(QUIETLY): Come on, Lois, I don't want to do that.",
#  'Your father and I have nothing in common.',
#  '(SUSTAINED FARTING)  (CONTINUES FARTING) Oh yeah!',
#  'Whew!',
#  "(CONTINUES FARTING) I'm so sorry.",
#  "Aw, this is your big moment and I'm ruining it.",
#  'Peter, what the hell are you doing?',
#  "Well, if we're talking about new hobbies",
#  'You can put it in your bathroom  or anywhere you want to feel peaceful.',
#  "I always liked the violin,  'cause it kind of has",
#  'Hey, you know what? Maybe you guys can learn an instrument, too,',
#  "Yeah, no offense, muchacho, but I don't know",
#  'Come on, guys, it could be cool.',
#  'Girls do like guys in a band.',
#  '(CHUCKLES): Oh, Quagmire, you are so predictable.',
#  'See? That\'s how you do \\"muchacho.\\"  And, you know, there\'s four of us',
#  'We could be a string quartet.',
#  'But first you guys got to do one thing for me.',
#  'I want you to put me in the booth.',
#  'Aw, yeah, sure, no problem.',
#  "Sure. Let's do it!",
#  'Wow. Thanks, guys.',
#  '(THUD) Hey, guys, guys, put him back up.',
#  '(LOWERING PITCH)  (THUD) (GIGGLES)',
#  'This is gonna be a blast.',
#  '- Hey, Carter.',
#  'Y-You have a butler? Then why am I here?',
#  " What? That's stupid.",
#  'See, this right here,  this is the one-percenter',
#  '9-percenter ass down  and read me the comics.',
#  'Okay. The Wizard of Id is addressing his subjects.',
#  ' Yes.',
#  '(PETER PLAYING OUT OF TUNE)  Okay, hang on, hang on, hang on.',
#  'Peter, what note are you playing?',
#  "Haven't you been practicing?",
#  "But I've been doing other violin stuff.",
#  'Wow, that looks sharp.',
#  'Ew, Peter, those tails are soaking wet.',
#  'Brian! Get in here!',
#  "I'm done with my bath.",
#  ' What? Why do I have to wear a wig?',
#  'Thank you, Penelope.',
#  'But first, grab that Gold Bond and powder my speed bag.',
#  'Wow, so you can just bypass all that gridlock?',
#  "And that's not all I also use it  to throw boxes of frogs",
#  'Boy, I could really get used to this rich guy stuff.',
#  'Them that have it   Get more of it ',
#  'Less they need it   The more they love it ',
#  'And it sticks to them   Like glue ',
#  'Funny, funny, funny what money can do ',
#  "He'll confess   Money can't buy ",
#  'Happiness   Ask the poor man ',
#  "He don't doubt   But he'd rather be miserable",
#  'If you spend it   Please be wiser ',
#  "If you save it   You're a miser ",
#  "You don't want it   You're cuckoo ",
#  'Funny, funny, funny what money can do ',
#  'Some skank I used to bang is getting married,',
#  " Wow, a wedding that's awesome!",
#  '(PLAYING \\"WEDDING MARCH\\" WITH PETER OUT OF TUNE)',
#  'Wait, hold on, hold on.',
#  "Well, I was that's how I got revved up to perform.",
#  'Yeah, this was your idea in the first place,',
#  "Peter, you're out of the group.",
#  'Well, fine. Screw you guys!',
#  'Wow, he seemed pretty angry.',
#  'Can I see your ID, please?',
#  'Uh, sir, that lady who came in and ate all the pies is back.',
#  'See if you can tell me where Waldo is.',
#  "Damn it! I've been stuck on that page for two days.",
#  "Hey, that's terrific, Carter!",
#  'That sounds like a great idea.',
#  'What are you talking about?',
#  "Didn't you hear him? I'm all healed.",
#  'What are you saying?',
#  "Now, before I go,  I'm just gonna old-man",
#  '(SIGHS)  (SIGHS)',
#  '(SIGHS)  Now, to take an old man pee.',
#  '(DOOR OPENS)  Ow. Ow. (SHORT SPLASHES)',
#  'Ow.',
#  'Ow.',
#  'Ow.',
#  'Ow. Ow.',
#  'Oh, Brian, just in time for dinner.',
#  'Eh, what else you got?',
#  "If Peter said that,  you all would've lost",
#  'Ã\x89tienne will whip you up an egg dish with some shallots',
#  'He climbed into my bed when I was 11.',
#  'Yeah, I guess I got used  to being a little pampered',
#  "Some of the other kids don't like it.",
#  "He thinks he's better than us.",
#  "I don't know. 9:00?",
#  "Look, it's not even about the stuff.",
#  'Wait a minute! Of course!',
#  'I offended Carter by offering to work for him.',
#  'He wanted a pal.',
#  "We all know you don't care about Carter.",
#  "No, no, no. He knows I'm his friend.",
#  '(GASPS) Bo Peep!',
#  "Um you've got a friend in me?",
#  'I-I thought you were rehearsing with the guys.',
#  'Oh, and they also taught me  that if your hand is bigger than',
#  "I was in the hospital? You weren't there for it.",
#  "Peter, I'm not falling for your trick,  but if you're upset about the guys",
#  'You never even practiced.',
#  "Maybe you're right. I guess  guess I could've been a",
#  'Maybe you could find a teacher who could help you learn,',
#  "I'll take some lessons.",
#  'How does a guy like me stay fresh  I use Fat Guys Deodorant.',
#  "Whether you're sitting, leaning,  lying down or sitting,",
#  'And now for the confusing commercial backstory.',
#  'Yeah, be right there, buddy.',
#  'Mr. Pewterschmidt, you have a visitor.',
#  'So, what are we drinking?',
#  'Get the hell out of here!',
#  "And besides, I'm off to the spa down at the club.",
#  "Oh, yeah, that's the stuff.",
#  'Yeah, (BLEEP) that sign.',
#  ' Thanks.',
#  'Let me just test this out quickly.',
#  'Yeah, that works. Okay, now you go.',
#  '(PLAYING SCALES)  Those scales sound terrible!',
#  'You fat and lazy! You leave now!',
#  "I really let 'em down.",
#  'You no try hard enough!',
#  "I'm trying! I'm trying!",
#  '(CRYING, PLAYING FASTER AND BETTER)  (SCREAMING)',
#  'Is somebody making a Cuban sandwich?',
#  "(MUTTERING GIBBERISH)  Brian, what's up?",
#  'Why are you engaging in cartoon profanity?',
#  "- I'm just so mad.",
#  'You know, about the friendship?',
#  'All right, fine, it was about the money.',
#  ' Yes, I know.',
#  'I never said it was my helicopter.',
#  'The implication was that it was a regular part of your life.',
#  'Anyway, I know this makes me sound awful, but I almost wish',
#  "Yeah, but he's not.",
#  "But he isn't. But he should be.",
#  "Come on, it'd be temporary,  just until he realizes I'm a great hang.",
#  'Okay. I get it. I get it.',
#  "What was I thinking? He he's your grandfather.",
#  'What? What did he say about me?',
#  "Um, he said you couldn't cut it as a member of One Direction.",
#  'Zayn is gone!',
#  'Oh, he definitely knows.',
#  "Okay, I'm pretty sure you're manipulating me,",
#  "Really? What if I'm not good enough?",
#  "We decided we'd rather be lousy with you than great without you.",
#  "- That's fair.",
#  'Will you come and play the wedding with us?',
#  "You guys won't regret this, and don't you worry.",
#  '(GROANING) Tell them the truth!',
#  "I'm the one who takes too long to get ready.",
#  'Peter!',
#  "(WATER RUNNING)  Okay, Brian, Carter's in the shower.",
#  'As soon as he comes out, we spray this right in his eyes.',
#  "Oh, it's just tap water from Flint, Michigan.",
#  'Aah! Son of a bitch! My eyes!',
#  'Carter, what happened?',
#  'Aah! My face! Aah!',
#  'Oh, my God!',
#  'Who did this? Who are you?',
#  "I did this, and it's made me realize  that I was blinded by",
#  "  Looks like we've learned a lot, and my face is better.",
#  "God, I'm so nervous.",
#  'Yes, Peter. You play away.',
#  'Just do the best you can.',
#  '(PLAYING \\"WEDDING MARCH\\")  (PLAYING A BEAUTIFUL SOLO)',
#  '(APPLAUSE)  Peter, that was amazing!',
#  'I know. Those lessons really paid off!',
#  'Not a chance. Mr. Washy Washy took all the joy out of this.',
#  "I hate life, and I'm never doing this again!",
#  "Oh, what a night   Late December back in '63 ",
#  'What a very special time for me   As I remember, what a night ',
#  'Oh, what a night      ',
#  " I got to say, some days I wish  I didn't have a sister.",
#  'Oh  - What?',
#  ' Nothing.',
#  'I did not.',
#  "Good evening, I'm Tom Tucker.",
#  'But first, Quahog says good-bye  to an old friend.',
#  'The restaurant has gone into foreclosure,',
#  'Medieval Castle? I love that place.',
#  'Guys, we should go to that auction tomorrow and buy it.',
#  "I bet it'd be even more fun  than when I went to White Castle.",
#  "(GROANING)  What's wrong with you?",
#  "Oh, it's my back. It's killing me.",
#  "No, this time it's not a bit.",
#  'I must have jacked it up playing sports  and not trying to dance like BeyoncÃ©.',
#  'I better tell Lois.',
#  "Then she'll drive me to the doctor,  and I hate being in the car with her.",
#  'OTH:  Oh, oh, oh   Oh, oh, oh, oh, oh ',
#  "Shut the door, baby, don't say a word ",
#  '(INDISTINCT CHATTER)  There it is, guys. Aw,',
#  "We just got to win this auction,  and then we'll have our own castle.",
#  "Good afternoon, and welcome to today's auction.",
#  'Wacky Waving Inflatable Arm-Flailing  Tubeman Warehouse and Emporium.',
#  'Due to the presence of black mold,  discarded half-eaten turkey legs,',
#  'Do I hear an opening bid? Anyone.',
#  ' Midas Muffler shop?',
#  "Two bits. That's 25 cents in the Old West.",
#  'This paper bag, which could be full of money or my socks.',
#  'We have an intriguing mystery bag.',
#  'Two bits and a cardboard box,  which may or may not',
#  'I have ever been a part of.',
#  '50 kroner.',
#  'Do I hear a much higher bid, followed by shocked murmuring?',
#  "- I'm shocked.",
#  "We're all shocked.",
#  "Peter, do something. I can't.",
#  'Due to my 12:00 noon court appointment  as part of a crippling',
#  ...]

# %%
def preprocess_sentence(sentence):
  sentence = sentence.lower().strip()
  # creating a space between a word and the punctuation following it
  # eg: "he is a boy." => "he is a boy ."
  sentence = re.sub(r"([?.!,])", r" \1 ", sentence)
  sentence = re.sub(r'[" "]+', " ", sentence)
  # replacing everything with space except (a-z, A-Z, ".", "?", "!", ",")
  sentence = re.sub(r"[^a-zA-Z?.!,]+", " ", sentence)
  sentence = sentence.strip()
  # adding a start and an end token to the sentence
  return sentence
output = predict('Stupid Meg')
# Out:
# Input: Stupid Meg
# Output: Aw, man, no, no, no, no, no, no.

# %%
def evaluate(sentence):
  sentence = preprocess_sentence(sentence)

  sentence = tf.expand_dims(
      START_TOKEN + tokenizer.encode(sentence) + END_TOKEN, axis=0)

  output = tf.expand_dims(START_TOKEN, 0)

  for i in range(MAX_LENGTH):
    predictions = model(inputs=[sentence, output], training=False)

    # select the last word from the seq_len dimension
    predictions = predictions[:, -1:, :]
    predicted_id = tf.cast(tf.argmax(predictions, axis=-1), tf.int32)

    # return the result if the predicted_id is equal to the end token
    if tf.equal(predicted_id, END_TOKEN[0]):
      break

    # concatenated the predicted_id to the output which is given to the decoder
    # as its input.
    output = tf.concat([output, predicted_id], axis=-1)

  return tf.squeeze(output, axis=0)


def predict(sentence):
  prediction = evaluate(sentence)

  predicted_sentence = tokenizer.decode(
      [i for i in prediction if i < tokenizer.vocab_size])

  print('Input: {}'.format(sentence))
  print('Output: {}'.format(predicted_sentence))

  return predicted_sentence

# %%
learning_rate = CustomSchedule(D_MODEL)

optimizer = tf.keras.optimizers.Adam(
    learning_rate, beta_1=0.9, beta_2=0.98, epsilon=1e-9)

def accuracy(y_true, y_pred):
  # ensure labels have shape (batch_size, MAX_LENGTH - 1)
  y_true = tf.reshape(y_true, shape=(-1, MAX_LENGTH - 1))
  return tf.keras.metrics.sparse_categorical_accuracy(y_true, y_pred)

model.compile(optimizer=optimizer, loss=loss_function, metrics=[accuracy])
EPOCHS = 20

model.fit(dataset, epochs=EPOCHS)
# Out:
# Epoch 1/20
# 112/112 [==============================] - 180s 2s/step - loss: 2.3644 - accuracy: 0.0256
# Epoch 2/20
# 112/112 [==============================] - 146s 1s/step - loss: 2.1721 - accuracy: 0.0288
# Epoch 3/20
# 112/112 [==============================] - 148s 1s/step - loss: 1.9020 - accuracy: 0.0387
# Epoch 4/20
# 112/112 [==============================] - 146s 1s/step - loss: 1.7358 - accuracy: 0.0548
# Epoch 5/20
# 112/112 [==============================] - 154s 1s/step - loss: 1.5975 - accuracy: 0.0633
# Epoch 6/20
# 112/112 [==============================] - 146s 1s/step - loss: 1.4812 - accuracy: 0.0724
# Epoch 7/20
# 112/112 [==============================] - 148s 1s/step - loss: 1.3931 - accuracy: 0.0796
# Epoch 8/20
# 112/112 [==============================] - 146s 1s/step - loss: 1.3216 - accuracy: 0.0869
# Epoch 9/20
# 112/112 [==============================] - 148s 1s/step - loss: 1.2576 - accuracy: 0.0922
# Epoch 10/20
# 112/112 [==============================] - 144s 1s/step - loss: 1.2008 - accuracy: 0.0976
# Epoch 11/20
# 112/112 [==============================] - 148s 1s/step - loss: 1.1466 - accuracy: 0.1030
# Epoch 12/20
# 112/112 [==============================] - 175s 2s/step - loss: 1.0920 - accuracy: 0.1086
# Epoch 13/20
# 112/112 [==============================] - 154s 1s/step - loss: 1.0344 - accuracy: 0.1148
# Epoch 14/20
# 112/112 [==============================] - 147s 1s/step - loss: 0.9763 - accuracy: 0.1216
# Epoch 15/20
# 112/112 [==============================] - 146s 1s/step - loss: 0.9147 - accuracy: 0.1293
# Epoch 16/20
# 112/112 [==============================] - 145s 1s/step - loss: 0.8516 - accuracy: 0.1373
# Epoch 17/20
# 112/112 [==============================] - 144s 1s/step - loss: 0.7834 - accuracy: 0.1469
# Epoch 18/20
# 112/112 [==============================] - 144s 1s/step - loss: 0.7130 - accuracy: 0.1573
# Epoch 19/20
# 112/112 [==============================] - 144s 1s/step - loss: 0.6382 - accuracy: 0.1691
# Epoch 20/20
# 112/112 [==============================] - 143s 1s/step - loss: 0.5660 - accuracy: 0.1811

# %%
def scaled_dot_product_attention(query, key, value, mask):
  """Calculate the attention weights. """
  matmul_qk = tf.matmul(query, key, transpose_b=True)

  # scale matmul_qk
  depth = tf.cast(tf.shape(key)[-1], tf.float32)
  logits = matmul_qk / tf.math.sqrt(depth)

  # add the mask to zero out padding tokens
  if mask is not None:
    logits += (mask * -1e9)

  # softmax is normalized on the last axis (seq_len_k)
  attention_weights = tf.nn.softmax(logits, axis=-1)

  output = tf.matmul(attention_weights, value)

  return output
class MultiHeadAttention(tf.keras.layers.Layer):

  def __init__(self, d_model, num_heads, name="multi_head_attention"):
    super(MultiHeadAttention, self).__init__(name=name)
    self.num_heads = num_heads
    self.d_model = d_model

    assert d_model % self.num_heads == 0

    self.depth = d_model // self.num_heads

    self.query_dense = tf.keras.layers.Dense(units=d_model)
    self.key_dense = tf.keras.layers.Dense(units=d_model)
    self.value_dense = tf.keras.layers.Dense(units=d_model)

    self.dense = tf.keras.layers.Dense(units=d_model)

  def split_heads(self, inputs, batch_size):
    inputs = tf.reshape(
        inputs, shape=(batch_size, -1, self.num_heads, self.depth))
    return tf.transpose(inputs, perm=[0, 2, 1, 3])

  def call(self, inputs):
    query, key, value, mask = inputs['query'], inputs['key'], inputs[
        'value'], inputs['mask']
    batch_size = tf.shape(query)[0]

    # linear layers
    query = self.query_dense(query)
    key = self.key_dense(key)
    value = self.value_dense(value)

    # split heads
    query = self.split_heads(query, batch_size)
    key = self.split_heads(key, batch_size)
    value = self.split_heads(value, batch_size)

    # scaled dot-product attention
    scaled_attention = scaled_dot_product_attention(query, key, value, mask)

    scaled_attention = tf.transpose(scaled_attention, perm=[0, 2, 1, 3])

    # concatenation of heads
    concat_attention = tf.reshape(scaled_attention,
                                  (batch_size, -1, self.d_model))

    # final linear layer
    outputs = self.dense(concat_attention)

    return outputs
def create_padding_mask(x):
  mask = tf.cast(tf.math.equal(x, 0), tf.float32)
  # (batch_size, 1, 1, sequence length)
  return mask[:, tf.newaxis, tf.newaxis, :]
def create_look_ahead_mask(x):
  seq_len = tf.shape(x)[1]
  look_ahead_mask = 1 - tf.linalg.band_part(tf.ones((seq_len, seq_len)), -1, 0)
  padding_mask = create_padding_mask(x)
  return tf.maximum(look_ahead_mask, padding_mask)
class PositionalEncoding(tf.keras.layers.Layer):

  def __init__(self, position, d_model):
    super(PositionalEncoding, self).__init__()
    self.pos_encoding = self.positional_encoding(position, d_model)

  def get_angles(self, position, i, d_model):
    angles = 1 / tf.pow(10000, (2 * (i // 2)) / tf.cast(d_model, tf.float32))
    return position * angles

  def positional_encoding(self, position, d_model):
    angle_rads = self.get_angles(
        position=tf.range(position, dtype=tf.float32)[:, tf.newaxis],
        i=tf.range(d_model, dtype=tf.float32)[tf.newaxis, :],
        d_model=d_model)
    # apply sin to even index in the array
    sines = tf.math.sin(angle_rads[:, 0::2])
    # apply cos to odd index in the array
    cosines = tf.math.cos(angle_rads[:, 1::2])

    pos_encoding = tf.concat([sines, cosines], axis=-1)
    pos_encoding = pos_encoding[tf.newaxis, ...]
    return tf.cast(pos_encoding, tf.float32)

  def call(self, inputs):
    return inputs + self.pos_encoding[:, :tf.shape(inputs)[1], :]
def encoder_layer(units, d_model, num_heads, dropout, name="encoder_layer"):
  inputs = tf.keras.Input(shape=(None, d_model), name="inputs")
  padding_mask = tf.keras.Input(shape=(1, 1, None), name="padding_mask")

  attention = MultiHeadAttention(
      d_model, num_heads, name="attention")({
          'query': inputs,
          'key': inputs,
          'value': inputs,
          'mask': padding_mask
      })
  attention = tf.keras.layers.Dropout(rate=dropout)(attention)
  attention = tf.keras.layers.LayerNormalization(
      epsilon=1e-6)(inputs + attention)

  outputs = tf.keras.layers.Dense(units=units, activation='relu')(attention)
  outputs = tf.keras.layers.Dense(units=d_model)(outputs)
  outputs = tf.keras.layers.Dropout(rate=dropout)(outputs)
  outputs = tf.keras.layers.LayerNormalization(
      epsilon=1e-6)(attention + outputs)

  return tf.keras.Model(
      inputs=[inputs, padding_mask], outputs=outputs, name=name)
sample_encoder_layer = encoder_layer(
    units=512,
    d_model=128,
    num_heads=4,
    dropout=0.3,
    name="sample_encoder_layer")

def encoder(vocab_size,
            num_layers,
            units,
            d_model,
            num_heads,
            dropout,
            name="encoder"):
  inputs = tf.keras.Input(shape=(None,), name="inputs")
  padding_mask = tf.keras.Input(shape=(1, 1, None), name="padding_mask")

  embeddings = tf.keras.layers.Embedding(vocab_size, d_model)(inputs)
  embeddings *= tf.math.sqrt(tf.cast(d_model, tf.float32))
  embeddings = PositionalEncoding(vocab_size, d_model)(embeddings)

  outputs = tf.keras.layers.Dropout(rate=dropout)(embeddings)

  for i in range(num_layers):
    outputs = encoder_layer(
        units=units,
        d_model=d_model,
        num_heads=num_heads,
        dropout=dropout,
        name="encoder_layer_{}".format(i),
    )([outputs, padding_mask])

  return tf.keras.Model(
      inputs=[inputs, padding_mask], outputs=outputs, name=name)
sample_encoder = encoder(
    vocab_size=8192,
    num_layers=2,
    units=512,
    d_model=128,
    num_heads=4,
    dropout=0.3,
    name="sample_encoder")

def decoder_layer(units, d_model, num_heads, dropout, name="decoder_layer"):
  inputs = tf.keras.Input(shape=(None, d_model), name="inputs")
  enc_outputs = tf.keras.Input(shape=(None, d_model), name="encoder_outputs")
  look_ahead_mask = tf.keras.Input(
      shape=(1, None, None), name="look_ahead_mask")
  padding_mask = tf.keras.Input(shape=(1, 1, None), name='padding_mask')

  attention1 = MultiHeadAttention(
      d_model, num_heads, name="attention_1")(inputs={
          'query': inputs,
          'key': inputs,
          'value': inputs,
          'mask': look_ahead_mask
      })
  attention1 = tf.keras.layers.LayerNormalization(
      epsilon=1e-6)(attention1 + inputs)

  attention2 = MultiHeadAttention(
      d_model, num_heads, name="attention_2")(inputs={
          'query': attention1,
          'key': enc_outputs,
          'value': enc_outputs,
          'mask': padding_mask
      })
  attention2 = tf.keras.layers.Dropout(rate=dropout)(attention2)
  attention2 = tf.keras.layers.LayerNormalization(
      epsilon=1e-6)(attention2 + attention1)

  outputs = tf.keras.layers.Dense(units=units, activation='relu')(attention2)
  outputs = tf.keras.layers.Dense(units=d_model)(outputs)
  outputs = tf.keras.layers.Dropout(rate=dropout)(outputs)
  outputs = tf.keras.layers.LayerNormalization(
      epsilon=1e-6)(outputs + attention2)

  return tf.keras.Model(
      inputs=[inputs, enc_outputs, look_ahead_mask, padding_mask],
      outputs=outputs,
      name=name)
sample_decoder_layer = decoder_layer(
    units=512,
    d_model=128,
    num_heads=4,
    dropout=0.3,
    name="sample_decoder_layer")

def decoder(vocab_size,
            num_layers,
            units,
            d_model,
            num_heads,
            dropout,
            name='decoder'):
  inputs = tf.keras.Input(shape=(None,), name='inputs')
  enc_outputs = tf.keras.Input(shape=(None, d_model), name='encoder_outputs')
  look_ahead_mask = tf.keras.Input(
      shape=(1, None, None), name='look_ahead_mask')
  padding_mask = tf.keras.Input(shape=(1, 1, None), name='padding_mask')
  
  embeddings = tf.keras.layers.Embedding(vocab_size, d_model)(inputs)
  embeddings *= tf.math.sqrt(tf.cast(d_model, tf.float32))
  embeddings = PositionalEncoding(vocab_size, d_model)(embeddings)

  outputs = tf.keras.layers.Dropout(rate=dropout)(embeddings)

  for i in range(num_layers):
    outputs = decoder_layer(
        units=units,
        d_model=d_model,
        num_heads=num_heads,
        dropout=dropout,
        name='decoder_layer_{}'.format(i),
    )(inputs=[outputs, enc_outputs, look_ahead_mask, padding_mask])

  return tf.keras.Model(
      inputs=[inputs, enc_outputs, look_ahead_mask, padding_mask],
      outputs=outputs,
      name=name)
sample_decoder = decoder(
    vocab_size=8192,
    num_layers=2,
    units=512,
    d_model=128,
    num_heads=4,
    dropout=0.3,
    name="sample_decoder")

def transformer(vocab_size,
                num_layers,
                units,
                d_model,
                num_heads,
                dropout,
                name="transformer"):
  inputs = tf.keras.Input(shape=(None,), name="inputs")
  dec_inputs = tf.keras.Input(shape=(None,), name="dec_inputs")

  enc_padding_mask = tf.keras.layers.Lambda(
      create_padding_mask, output_shape=(1, 1, None),
      name='enc_padding_mask')(inputs)
  # mask the future tokens for decoder inputs at the 1st attention block
  look_ahead_mask = tf.keras.layers.Lambda(
      create_look_ahead_mask,
      output_shape=(1, None, None),
      name='look_ahead_mask')(dec_inputs)
  # mask the encoder outputs for the 2nd attention block
  dec_padding_mask = tf.keras.layers.Lambda(
      create_padding_mask, output_shape=(1, 1, None),
      name='dec_padding_mask')(inputs)

  enc_outputs = encoder(
      vocab_size=vocab_size,
      num_layers=num_layers,
      units=units,
      d_model=d_model,
      num_heads=num_heads,
      dropout=dropout,
  )(inputs=[inputs, enc_padding_mask])

  dec_outputs = decoder(
      vocab_size=vocab_size,
      num_layers=num_layers,
      units=units,
      d_model=d_model,
      num_heads=num_heads,
      dropout=dropout,
  )(inputs=[dec_inputs, enc_outputs, look_ahead_mask, dec_padding_mask])

  outputs = tf.keras.layers.Dense(units=vocab_size, name="outputs")(dec_outputs)

  return tf.keras.Model(inputs=[inputs, dec_inputs], outputs=outputs, name=name)
sample_transformer = transformer(
    vocab_size=8192,
    num_layers=4,
    units=512,
    d_model=128,
    num_heads=4,
    dropout=0.3,
    name="sample_transformer")

tf.keras.backend.clear_session()

# Hyper-parameters
NUM_LAYERS = 2
D_MODEL = 256
NUM_HEADS = 8
UNITS = 512
DROPOUT = 0.1

model = transformer(
    vocab_size=VOCAB_SIZE,
    num_layers=NUM_LAYERS,
    units=UNITS,
    d_model=D_MODEL,
    num_heads=NUM_HEADS,
    dropout=DROPOUT)
def loss_function(y_true, y_pred):
  y_true = tf.reshape(y_true, shape=(-1, MAX_LENGTH - 1))
  
  loss = tf.keras.losses.SparseCategoricalCrossentropy(
      from_logits=True, reduction='none')(y_true, y_pred)

  mask = tf.cast(tf.not_equal(y_true, 0), tf.float32)
  loss = tf.multiply(loss, mask)

  return tf.reduce_mean(loss)
class CustomSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):

  def __init__(self, d_model, warmup_steps=4000):
    super(CustomSchedule, self).__init__()

    self.d_model = d_model
    self.d_model = tf.cast(self.d_model, tf.float32)

    self.warmup_steps = warmup_steps

  def __call__(self, step):
    arg1 = tf.math.rsqrt(step)
    arg2 = step * (self.warmup_steps**-1.5)

    return tf.math.rsqrt(self.d_model) * tf.math.minimum(arg1, arg2)
sample_learning_rate = CustomSchedule(d_model=128)

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

try:
  # The %tensorflow_version magic only works in colab.
  # %tensorflow_version 2.x
except Exception:
  pass
import tensorflow as tf
tf.random.set_seed(1234)

# !pip install tensorflow-datasets==1.2.0
import tensorflow_datasets as tfds

import os
import re
import numpy as np
import matplotlib.pyplot as plt

# Build tokenizer using tfds for both questions and answers
tokenizer = tfds.features.text.SubwordTextEncoder.build_from_corpus(
    questions + answers, target_vocab_size=2**13)

# Define start and end token to indicate the start and end of a sentence
START_TOKEN, END_TOKEN = [tokenizer.vocab_size], [tokenizer.vocab_size + 1]

# Vocabulary size plus start and end token
VOCAB_SIZE = tokenizer.vocab_size + 2
# Maximum sentence length
MAX_LENGTH = 40


# Tokenize, filter and pad sentences
def tokenize_and_filter(inputs, outputs):
  tokenized_inputs, tokenized_outputs = [], []
  
  for (sentence1, sentence2) in zip(inputs, outputs):
    # tokenize sentence
    sentence1 = START_TOKEN + tokenizer.encode(sentence1) + END_TOKEN
    sentence2 = START_TOKEN + tokenizer.encode(sentence2) + END_TOKEN
    # check tokenized sentence max length
    if len(sentence1) <= MAX_LENGTH and len(sentence2) <= MAX_LENGTH:
      tokenized_inputs.append(sentence1)
      tokenized_outputs.append(sentence2)
  
  # pad tokenized sentences
  tokenized_inputs = tf.keras.preprocessing.sequence.pad_sequences(
      tokenized_inputs, maxlen=MAX_LENGTH, padding='post')
  tokenized_outputs = tf.keras.preprocessing.sequence.pad_sequences(
      tokenized_outputs, maxlen=MAX_LENGTH, padding='post')
  
  return tokenized_inputs, tokenized_outputs


questions, answers = tokenize_and_filter(questions, answers)
MAX_SAMPLES = 50000
print('Vocab size: {}'.format(VOCAB_SIZE))
print('Number of samples: {}'.format(len(questions)))
BATCH_SIZE = 64
BUFFER_SIZE = 20000

# decoder inputs use the previous target as input
# remove START_TOKEN from targets
dataset = tf.data.Dataset.from_tensor_slices((
    {
        'inputs': questions,
        'dec_inputs': answers[:, :-1]
    },
    {
        'outputs': answers[:, 1:]
    },
))

dataset = dataset.cache()
dataset = dataset.shuffle(BUFFER_SIZE)
dataset = dataset.batch(BATCH_SIZE)
dataset = dataset.prefetch(tf.data.experimental.AUTOTUNE)
# Out:
# Requirement already satisfied: tensorflow-datasets==1.2.0 in /opt/anaconda3/lib/python3.7/site-packages (1.2.0)
# Requirement already satisfied: absl-py in /opt/anaconda3/lib/python3.7/site-packages (from tensorflow-datasets==1.2.0) (0.8.1)
# Requirement already satisfied: protobuf>=3.6.1 in /opt/anaconda3/lib/python3.7/site-packages (from tensorflow-datasets==1.2.0) (3.9.2)
# Requirement already satisfied: promise in /opt/anaconda3/lib/python3.7/site-packages (from tensorflow-datasets==1.2.0) (2.2.1)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.7/site-packages (from tensorflow-datasets==1.2.0) (1.17.3)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.7/site-packages (from tensorflow-datasets==1.2.0) (1.13.0)
# Requirement already satisfied: attrs in /opt/anaconda3/lib/python3.7/site-packages (from tensorflow-datasets==1.2.0) (19.3.0)
# Requirement already satisfied: psutil in /opt/anaconda3/lib/python3.7/site-packages (from tensorflow-datasets==1.2.0) (5.6.5)
# Requirement already satisfied: tensorflow-metadata in /opt/anaconda3/lib/python3.7/site-packages (from tensorflow-datasets==1.2.0) (0.15.1)
# Requirement already satisfied: future in /opt/anaconda3/lib/python3.7/site-packages (from tensorflow-datasets==1.2.0) (0.18.2)
# Requirement already satisfied: termcolor in /opt/anaconda3/lib/python3.7/site-packages (from tensorflow-datasets==1.2.0) (1.1.0)
# Requirement already satisfied: wrapt in /opt/anaconda3/lib/python3.7/site-packages (from tensorflow-datasets==1.2.0) (1.11.2)
# Requirement already satisfied: requests>=2.19.0 in /opt/anaconda3/lib/python3.7/site-packages (from tensorflow-datasets==1.2.0) (2.22.0)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.7/site-packages (from tensorflow-datasets==1.2.0) (4.38.0)
# Requirement already satisfied: dill in /opt/anaconda3/lib/python3.7/site-packages (from tensorflow-datasets==1.2.0) (0.3.1.1)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.7/site-packages (from protobuf>=3.6.1->tensorflow-datasets==1.2.0) (41.6.0.post20191030)
# Requirement already satisfied: googleapis-common-protos in /opt/anaconda3/lib/python3.7/site-packages (from tensorflow-metadata->tensorflow-datasets==1.2.0) (1.6.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/anaconda3/lib/python3.7/site-packages (from requests>=2.19.0->tensorflow-datasets==1.2.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/anaconda3/lib/python3.7/site-packages (from requests>=2.19.0->tensorflow-datasets==1.2.0) (1.24.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.7/site-packages (from requests>=2.19.0->tensorflow-datasets==1.2.0) (2019.9.11)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/anaconda3/lib/python3.7/site-packages (from requests>=2.19.0->tensorflow-datasets==1.2.0) (2.8)
# Vocab size: 7027
# Number of samples: 7123

# %%
corpus=[]
for i in range(len(content)):
    if content[i]=='\n':
        continue
    if i==20357:
        continue
    if content[i][2].islower():
        continue
    if content[i][-2]=='?' or content[i][-2]=='!' or content[i][-2]=='.':
        corpus.append(content[i])
    else:
        corpus.append(content[i]+content[i+1])
corpus=corpus[2:]
corpus=[x[2:].replace("\n", "") for x in corpus]
questions=[]
answers=[]
for i in range(len(corpus)):
    if i%2==0:
        answers.append(corpus[i])
    else:
        questions.append(corpus[i])

# %%
with open("data.txt") as f:
    content = f.readlines()
